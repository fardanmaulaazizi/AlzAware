# %%
import zipfile, os
local_zip = 'dataset.zip'
zip_ref = zipfile.ZipFile(local_zip,'r')
zip_ref.extractall()
zip_ref.close()

# %%
from distutils.dir_util import copy_tree, remove_tree

base_dir = "Alzheimer_s Dataset/"
root_dir = "./"
test_dir = base_dir + "test/"
train_dir = base_dir + "train/"
work_dir = root_dir + "dataset/"

if os.path.exists(work_dir):
    remove_tree(work_dir)
    

os.mkdir(work_dir)
copy_tree(train_dir, work_dir)
copy_tree(test_dir, work_dir)
print("Working Directory Contents:", os.listdir(work_dir))
# Out:
# Working Directory Contents: ['MildDemented', 'ModerateDemented', 'NonDemented', 'VeryMildDemented']

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator as IDG
import matplotlib.pyplot as plt
from random import randint
import numpy as np

ZOOM = [.99, 1.01]
BRIGHT_RANGE = [0.8, 1.2]
HORZ_FLIP = True
FILL_MODE = "constant"
DATA_FORMAT = "channels_last"

work_dr = IDG(
    rescale = 1./255, 
    brightness_range=BRIGHT_RANGE, 
    zoom_range=ZOOM, 
    data_format=DATA_FORMAT, 
    fill_mode=FILL_MODE, 
    horizontal_flip=HORZ_FLIP)
WORK_DIR = './dataset/'
IMG_SIZE = 128
IMAGE_SIZE = [128, 128]
DIM = (IMG_SIZE, IMG_SIZE)
train_data_gen = work_dr.flow_from_directory(
    directory=WORK_DIR, 
    target_size=DIM, 
    batch_size=6400, 
    shuffle=False)

def show_images(generator,y_pred=None):
    """
    Input: An image generator,predicted labels (optional)
    Output: Displays a grid of 9 images with lables
    """
    
    # get image lables
    Classes = [ 'MildDemented',
            'ModerateDemented',
            'NonDemented',
            'VeryMildDemented']
    labels =dict(zip([0,1,2,3], Classes))
    
    # get a batch of images
    x,y = generator.next()
    
    # display a grid of 9 images
    plt.figure(figsize=(10, 10))
    if y_pred is None:
        for i in range(9):
            ax = plt.subplot(3, 3, i + 1)
            idx = randint(0, 6400)
            plt.imshow(x[idx])
            plt.axis("off")
            plt.title("Class:{}".format(labels[np.argmax(y[idx])]))
                                                     
    else:
        for i in range(9):
            ax = plt.subplot(3, 3, i + 1)
            plt.imshow(x[i])
            plt.axis("off")
            plt.title("Actual:{} \nPredicted:{}".format(labels[np.argmax(y[i])],labels[y_pred[i]]))
    
# Display Train Images
show_images(train_data_gen)
# Memasukan data
train_data, train_labels = train_data_gen.next()
print(train_data.shape, train_labels.shape)
# Out:
# Found 6400 images belonging to 4 classes.
# (6400, 128, 128, 3) (6400, 4)

# %%
from sklearn.model_selection import train_test_split
train_data, test_data, train_labels, test_labels = train_test_split(train_data, train_labels, test_size = 0.4, random_state=11)
print(len(train_data), len(test_data))
# Out:
# 3840 2560

# %%
import tensorflow as tf
from tensorflow.keras import datasets, layers, models
model = tf.keras.models.Sequential([
          tf.keras.layers.Conv2D(128, (3, 3), activation = 'relu', input_shape = (128, 128, 3)),
          tf.keras.layers.MaxPooling2D(2, 2),
          tf.keras.layers.Conv2D(64, (3, 3), activation = 'relu'),
          tf.keras.layers.MaxPooling2D(2, 2),
          tf.keras.layers.Conv2D(32, (3, 3), activation = 'relu'),
          tf.keras.layers.MaxPooling2D(2, 2),
          tf.keras.layers.Flatten(),
          tf.keras.layers.Dense(500, activation = 'relu'),
          tf.keras.layers.Dense(200, activation = 'relu'),
          tf.keras.layers.Dense(4, activation = 'softmax')
])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 126, 126, 128)     3584
#
#  max_pooling2d (MaxPooling2D  (None, 63, 63, 128)      0
#  )
#
#  conv2d_1 (Conv2D)           (None, 61, 61, 64)        73792
#
#  max_pooling2d_1 (MaxPooling  (None, 30, 30, 64)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 28, 28, 32)        18464
#
#  max_pooling2d_2 (MaxPooling  (None, 14, 14, 32)       0
#  2D)
#
#  flatten (Flatten)           (None, 6272)              0
#
#  dense (Dense)               (None, 500)               3136500
#
#  dense_1 (Dense)             (None, 200)               100200
#
#  dense_2 (Dense)             (None, 4)                 804
#
# =================================================================
# Total params: 3,333,344
# Trainable params: 3,333,344
# Non-trainable params: 0
# _________________________________________________________________

# %%
from tensorflow import keras
from tensorflow.keras import datasets, layers, models
model.compile(optimizer=keras.optimizers.Adam(learning_rate=0.0001),
                              loss=tf.losses.CategoricalCrossentropy(),
                              metrics=['accuracy'])

history = model.fit(train_data, train_labels, epochs=50, 
                    validation_data=(test_data, test_labels))
# Out:
# Epoch 1/50
# 120/120 [==============================] - 131s 1s/step - loss: 1.0448 - accuracy: 0.4883 - val_loss: 1.0203 - val_accuracy: 0.4980
# Epoch 2/50
# 120/120 [==============================] - 127s 1s/step - loss: 0.9909 - accuracy: 0.5182 - val_loss: 0.9610 - val_accuracy: 0.5074
# Epoch 3/50
# 120/120 [==============================] - 128s 1s/step - loss: 0.9377 - accuracy: 0.5469 - val_loss: 0.9318 - val_accuracy: 0.5621
# Epoch 4/50
# 120/120 [==============================] - 127s 1s/step - loss: 0.8984 - accuracy: 0.5732 - val_loss: 0.8665 - val_accuracy: 0.5883
# Epoch 5/50
# 120/120 [==============================] - 127s 1s/step - loss: 0.8669 - accuracy: 0.5974 - val_loss: 0.8359 - val_accuracy: 0.6176
# Epoch 6/50
# 120/120 [==============================] - 127s 1s/step - loss: 0.8356 - accuracy: 0.6122 - val_loss: 0.8502 - val_accuracy: 0.5562
# Epoch 7/50
# 120/120 [==============================] - 127s 1s/step - loss: 0.7869 - accuracy: 0.6297 - val_loss: 0.7746 - val_accuracy: 0.6402
# Epoch 8/50
# 120/120 [==============================] - 127s 1s/step - loss: 0.7204 - accuracy: 0.6711 - val_loss: 0.7560 - val_accuracy: 0.6535
# Epoch 9/50
# 120/120 [==============================] - 127s 1s/step - loss: 0.6475 - accuracy: 0.7148 - val_loss: 0.6805 - val_accuracy: 0.6977
# Epoch 10/50
# 120/120 [==============================] - 127s 1s/step - loss: 0.5983 - accuracy: 0.7378 - val_loss: 0.6604 - val_accuracy: 0.7066
# Epoch 11/50
# 120/120 [==============================] - 128s 1s/step - loss: 0.5307 - accuracy: 0.7729 - val_loss: 0.6706 - val_accuracy: 0.7145
# Epoch 12/50
# 120/120 [==============================] - 128s 1s/step - loss: 0.4596 - accuracy: 0.8180 - val_loss: 0.5863 - val_accuracy: 0.7488
# Epoch 13/50
# 120/120 [==============================] - 128s 1s/step - loss: 0.4005 - accuracy: 0.8417 - val_loss: 0.5975 - val_accuracy: 0.7531
# Epoch 14/50
# 120/120 [==============================] - 128s 1s/step - loss: 0.3298 - accuracy: 0.8727 - val_loss: 0.5677 - val_accuracy: 0.7598
# Epoch 15/50
# 120/120 [==============================] - 128s 1s/step - loss: 0.2725 - accuracy: 0.9052 - val_loss: 0.5859 - val_accuracy: 0.7707
# Epoch 16/50
# 120/120 [==============================] - 128s 1s/step - loss: 0.2528 - accuracy: 0.9117 - val_loss: 0.6961 - val_accuracy: 0.7527
# Epoch 17/50
# 120/120 [==============================] - 128s 1s/step - loss: 0.2002 - accuracy: 0.9354 - val_loss: 0.4788 - val_accuracy: 0.8211
# Epoch 18/50
# 120/120 [==============================] - 128s 1s/step - loss: 0.1579 - accuracy: 0.9495 - val_loss: 0.5701 - val_accuracy: 0.7820
# Epoch 19/50
# 120/120 [==============================] - 130s 1s/step - loss: 0.1361 - accuracy: 0.9602 - val_loss: 0.6212 - val_accuracy: 0.7988
# Epoch 20/50
# 120/120 [==============================] - 128s 1s/step - loss: 0.0911 - accuracy: 0.9784 - val_loss: 0.5003 - val_accuracy: 0.8156
# Epoch 21/50
# 120/120 [==============================] - 128s 1s/step - loss: 0.0698 - accuracy: 0.9841 - val_loss: 0.5808 - val_accuracy: 0.8156
# Epoch 22/50
# 120/120 [==============================] - 128s 1s/step - loss: 0.0621 - accuracy: 0.9870 - val_loss: 0.4905 - val_accuracy: 0.8438
# Epoch 23/50
# 120/120 [==============================] - 129s 1s/step - loss: 0.0405 - accuracy: 0.9951 - val_loss: 0.4905 - val_accuracy: 0.8504
# Epoch 24/50
# 120/120 [==============================] - 128s 1s/step - loss: 0.0394 - accuracy: 0.9919 - val_loss: 0.4879 - val_accuracy: 0.8590
# Epoch 25/50
# 120/120 [==============================] - 128s 1s/step - loss: 0.0181 - accuracy: 0.9997 - val_loss: 0.5205 - val_accuracy: 0.8543
# Epoch 26/50
# 120/120 [==============================] - 128s 1s/step - loss: 0.0127 - accuracy: 0.9995 - val_loss: 0.5629 - val_accuracy: 0.8531
# Epoch 27/50
# 120/120 [==============================] - 128s 1s/step - loss: 0.0104 - accuracy: 0.9997 - val_loss: 0.6251 - val_accuracy: 0.8445
# Epoch 28/50
# 120/120 [==============================] - 128s 1s/step - loss: 0.0079 - accuracy: 1.0000 - val_loss: 0.5674 - val_accuracy: 0.8562
# Epoch 29/50
# 120/120 [==============================] - 128s 1s/step - loss: 0.0058 - accuracy: 1.0000 - val_loss: 0.5611 - val_accuracy: 0.8582
# Epoch 30/50
# 120/120 [==============================] - 129s 1s/step - loss: 0.0048 - accuracy: 1.0000 - val_loss: 0.6045 - val_accuracy: 0.8582
# Epoch 31/50
# 120/120 [==============================] - 128s 1s/step - loss: 0.0036 - accuracy: 1.0000 - val_loss: 0.5773 - val_accuracy: 0.8594
# Epoch 32/50
# 120/120 [==============================] - 129s 1s/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 0.6068 - val_accuracy: 0.8574
# Epoch 33/50
# 120/120 [==============================] - 129s 1s/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 0.5964 - val_accuracy: 0.8590
# Epoch 34/50
# 120/120 [==============================] - 129s 1s/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.6250 - val_accuracy: 0.8570
# Epoch 35/50
# 120/120 [==============================] - 129s 1s/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.6342 - val_accuracy: 0.8586
# Epoch 36/50
# 120/120 [==============================] - 128s 1s/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.6371 - val_accuracy: 0.8578
# Epoch 37/50
# 120/120 [==============================] - 128s 1s/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.6357 - val_accuracy: 0.8582
# Epoch 38/50
# 120/120 [==============================] - 128s 1s/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.6448 - val_accuracy: 0.8609
# Epoch 39/50
# 120/120 [==============================] - 129s 1s/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.6634 - val_accuracy: 0.8559
# Epoch 40/50
# 120/120 [==============================] - 128s 1s/step - loss: 9.4905e-04 - accuracy: 1.0000 - val_loss: 0.6587 - val_accuracy: 0.8648
# Epoch 41/50
# 120/120 [==============================] - 128s 1s/step - loss: 8.2603e-04 - accuracy: 1.0000 - val_loss: 0.6674 - val_accuracy: 0.8613
# Epoch 42/50
# 120/120 [==============================] - 128s 1s/step - loss: 7.2858e-04 - accuracy: 1.0000 - val_loss: 0.6819 - val_accuracy: 0.8602
# Epoch 43/50
# 120/120 [==============================] - 128s 1s/step - loss: 6.9462e-04 - accuracy: 1.0000 - val_loss: 0.6817 - val_accuracy: 0.8570
# Epoch 44/50
# 120/120 [==============================] - 128s 1s/step - loss: 5.9162e-04 - accuracy: 1.0000 - val_loss: 0.6793 - val_accuracy: 0.8648
# Epoch 45/50
# 120/120 [==============================] - 128s 1s/step - loss: 5.3441e-04 - accuracy: 1.0000 - val_loss: 0.6903 - val_accuracy: 0.8605
# Epoch 46/50
# 120/120 [==============================] - 130s 1s/step - loss: 4.7515e-04 - accuracy: 1.0000 - val_loss: 0.7001 - val_accuracy: 0.8645
# Epoch 47/50
# 120/120 [==============================] - 129s 1s/step - loss: 4.2859e-04 - accuracy: 1.0000 - val_loss: 0.7077 - val_accuracy: 0.8590
# Epoch 48/50
# 120/120 [==============================] - 129s 1s/step - loss: 3.8395e-04 - accuracy: 1.0000 - val_loss: 0.7186 - val_accuracy: 0.8609
# Epoch 49/50
# 120/120 [==============================] - 129s 1s/step - loss: 3.4419e-04 - accuracy: 1.0000 - val_loss: 0.7175 - val_accuracy: 0.8621
# Epoch 50/50
# 120/120 [==============================] - 129s 1s/step - loss: 3.0614e-04 - accuracy: 1.0000 - val_loss: 0.7286 - val_accuracy: 0.8598

# %%
#Plotting the trend of the metrics during training

fig, ax = plt.subplots(1, 2, figsize = (30, 5))
ax = ax.ravel()

for i, metric in enumerate(["accuracy", "loss"]):
    ax[i].plot(history.history[metric])
    ax[i].plot(history.history["val_" + metric])
    ax[i].set_title("Model {}".format(metric))
    ax[i].set_xlabel("Epochs")
    ax[i].set_ylabel(metric)
    ax[i].legend(["train", "test"])

# %%
# %matplotlib inline

import matplotlib.image  as mpimg
import matplotlib.pyplot as plt


acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(len(acc))

plt.plot(epochs, acc, 'r', label = 'Training Accuracy')
plt.plot(epochs, val_acc, 'b', label = 'Testing Accuracy')
plt.title('Training and Validation accuracy')
plt.legend(loc = 'best')
plt.show()

plt.plot(epochs, loss, 'r', label = 'Training Loss')
plt.plot(epochs, val_loss, 'b', label = 'Testing Loss')
plt.title('Training and Validation accuracy')
plt.legend(loc = 'best')
plt.show()

# %%
#Evaluating the model on the data

#train_scores = model.evaluate(train_data, train_labels)
#val_scores = model.evaluate(val_data, val_labels)
test_scores = model.evaluate(test_data, test_labels)

#print("Training Accuracy: %.2f%%"%(train_scores[1] * 100))
#print("Validation Accuracy: %.2f%%"%(val_scores[1] * 100))
print("Testing Accuracy: %.2f%%"%(test_scores[1] * 100))
# Out:
# 80/80 [==============================] - 15s 185ms/step - loss: 0.7286 - accuracy: 0.8598
# Testing Accuracy: 85.98%

# %%
#Predicting the test data

pred_labels = model.predict(test_data)
# Out:
# 80/80 [==============================] - 16s 192ms/step

# %%
#Print the classification report of the tested data

#Since the labels are softmax arrays, we need to roundoff to have it in the form of 0s and 1s,
#similar to the test_labels
from sklearn.metrics import classification_report, confusion_matrix
def roundoff(arr):
    """To round off according to the argmax of each predicted label array. """
    arr[np.argwhere(arr != arr.max())] = 0
    arr[np.argwhere(arr == arr.max())] = 1
    return arr

for labels in pred_labels:
    labels = roundoff(labels)

print(classification_report(test_labels, pred_labels, target_names=[ 'MildDemented',
            'ModerateDemented',
            'NonDemented',
            'VeryMildDemented']))
# Out:
#                   precision    recall  f1-score   support
#
#     MildDemented       0.84      0.73      0.78       368
# ModerateDemented       1.00      0.95      0.98        21
#      NonDemented       0.89      0.91      0.90      1275
# VeryMildDemented       0.82      0.84      0.83       896
#
#        micro avg       0.86      0.86      0.86      2560
#        macro avg       0.89      0.86      0.87      2560
#     weighted avg       0.86      0.86      0.86      2560
#      samples avg       0.86      0.86      0.86      2560

# %%
import seaborn as sns
pred_ls = np.argmax(pred_labels, axis=1)
test_ls = np.argmax(test_labels, axis=1)

conf_arr = confusion_matrix(test_ls, pred_ls)

plt.figure(figsize=(8, 6), dpi=80, facecolor='w', edgecolor='k')

ax = sns.heatmap(conf_arr, cmap='Greens', annot=True, fmt='d', xticklabels= [ 'MildDemented',
            'ModerateDemented',
            'NonDemented',
            'VeryMildDemented'],
                yticklabels=[ 'MildDemented',
            'ModerateDemented',
            'NonDemented',
            'VeryMildDemented'])

plt.title('Alzheimer\'s Disease Diagnosis')
plt.xlabel('Prediction')
plt.ylabel('Truth')
plt.show(ax)

# %%
model.save('modelAlzheimer.h5')

# %%
print(np.max(history.history['val_accuracy']))
print(np.min(history.history['val_accuracy']))
print(np.mean(history.history['val_accuracy']))
# Out:
# 0.8648437261581421
# 0.498046875
# 0.7887499940395355

# %%
print(np.max(history.history['val_loss']))
print(np.min(history.history['val_loss']))
print(np.mean(history.history['val_loss']))
# Out:
# 1.0203325748443604
# 0.4788338243961334
# 0.6591088175773621
