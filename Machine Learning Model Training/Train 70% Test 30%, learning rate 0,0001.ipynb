# %%
import zipfile, os
local_zip = 'dataset.zip'
zip_ref = zipfile.ZipFile(local_zip,'r')
zip_ref.extractall()
zip_ref.close()

# %%
from distutils.dir_util import copy_tree, remove_tree

base_dir = "Alzheimer_s Dataset/"
root_dir = "./"
test_dir = base_dir + "test/"
train_dir = base_dir + "train/"
work_dir = root_dir + "dataset/"

if os.path.exists(work_dir):
    remove_tree(work_dir)
    

os.mkdir(work_dir)
copy_tree(train_dir, work_dir)
copy_tree(test_dir, work_dir)
print("Working Directory Contents:", os.listdir(work_dir))
# Out:
# Working Directory Contents: ['MildDemented', 'ModerateDemented', 'NonDemented', 'VeryMildDemented']

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator as IDG
import matplotlib.pyplot as plt
from random import randint
import numpy as np

ZOOM = [.99, 1.01]
BRIGHT_RANGE = [0.8, 1.2]
HORZ_FLIP = True
FILL_MODE = "constant"
DATA_FORMAT = "channels_last"

work_dr = IDG(
    rescale = 1./255, 
    brightness_range=BRIGHT_RANGE, 
    zoom_range=ZOOM, 
    data_format=DATA_FORMAT, 
    fill_mode=FILL_MODE, 
    horizontal_flip=HORZ_FLIP)
WORK_DIR = './dataset/'
IMG_SIZE = 128
IMAGE_SIZE = [128, 128]
DIM = (IMG_SIZE, IMG_SIZE)
train_data_gen = work_dr.flow_from_directory(
    directory=WORK_DIR, 
    target_size=DIM, 
    batch_size=6400, 
    shuffle=False)

def show_images(generator,y_pred=None):
    """
    Input: An image generator,predicted labels (optional)
    Output: Displays a grid of 9 images with lables
    """
    
    # get image lables
    Classes = [ 'MildDemented',
            'ModerateDemented',
            'NonDemented',
            'VeryMildDemented']
    labels =dict(zip([0,1,2,3], Classes))
    
    # get a batch of images
    x,y = generator.next()
    
    # display a grid of 9 images
    plt.figure(figsize=(10, 10))
    if y_pred is None:
        for i in range(9):
            ax = plt.subplot(3, 3, i + 1)
            idx = randint(0, 6400)
            plt.imshow(x[idx])
            plt.axis("off")
            plt.title("Class:{}".format(labels[np.argmax(y[idx])]))
                                                     
    else:
        for i in range(9):
            ax = plt.subplot(3, 3, i + 1)
            plt.imshow(x[i])
            plt.axis("off")
            plt.title("Actual:{} \nPredicted:{}".format(labels[np.argmax(y[i])],labels[y_pred[i]]))
    
# Display Train Images
show_images(train_data_gen)
# Memasukan data
train_data, train_labels = train_data_gen.next()
print(train_data.shape, train_labels.shape)
# Out:
# Found 6400 images belonging to 4 classes.
# (6400, 128, 128, 3) (6400, 4)

# %%
from sklearn.model_selection import train_test_split
train_data, test_data, train_labels, test_labels = train_test_split(train_data, train_labels, test_size = 0.3, random_state=11)
print(len(train_data), len(test_data))
# Out:
# 4480 1920

# %%
import tensorflow as tf
from tensorflow.keras import datasets, layers, models
model = tf.keras.models.Sequential([
          tf.keras.layers.Conv2D(128, (3, 3), activation = 'relu', input_shape = (128, 128, 3)),
          tf.keras.layers.MaxPooling2D(2, 2),
          tf.keras.layers.Conv2D(64, (3, 3), activation = 'relu'),
          tf.keras.layers.MaxPooling2D(2, 2),
          tf.keras.layers.Conv2D(32, (3, 3), activation = 'relu'),
          tf.keras.layers.MaxPooling2D(2, 2),
          tf.keras.layers.Flatten(),
          tf.keras.layers.Dense(500, activation = 'relu'),
          tf.keras.layers.Dense(200, activation = 'relu'),
          tf.keras.layers.Dense(4, activation = 'softmax')
])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 126, 126, 128)     3584
#
#  max_pooling2d (MaxPooling2D  (None, 63, 63, 128)      0
#  )
#
#  conv2d_1 (Conv2D)           (None, 61, 61, 64)        73792
#
#  max_pooling2d_1 (MaxPooling  (None, 30, 30, 64)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 28, 28, 32)        18464
#
#  max_pooling2d_2 (MaxPooling  (None, 14, 14, 32)       0
#  2D)
#
#  flatten (Flatten)           (None, 6272)              0
#
#  dense (Dense)               (None, 500)               3136500
#
#  dense_1 (Dense)             (None, 200)               100200
#
#  dense_2 (Dense)             (None, 4)                 804
#
# =================================================================
# Total params: 3,333,344
# Trainable params: 3,333,344
# Non-trainable params: 0
# _________________________________________________________________

# %%
from tensorflow import keras
from tensorflow.keras import datasets, layers, models
model.compile(optimizer=keras.optimizers.Adam(learning_rate=0.0001),
                              loss=tf.losses.CategoricalCrossentropy(),
                              metrics=['accuracy'])

history = model.fit(train_data, train_labels, epochs=50, 
                    validation_data=(test_data, test_labels))
# Out:
# Epoch 1/50
# 140/140 [==============================] - 137s 973ms/step - loss: 1.0398 - accuracy: 0.4991 - val_loss: 0.9716 - val_accuracy: 0.5094
# Epoch 2/50
# 140/140 [==============================] - 136s 973ms/step - loss: 0.9597 - accuracy: 0.5272 - val_loss: 0.8991 - val_accuracy: 0.5776
# Epoch 3/50
# 140/140 [==============================] - 137s 981ms/step - loss: 0.9154 - accuracy: 0.5558 - val_loss: 0.8767 - val_accuracy: 0.5922
# Epoch 4/50
# 140/140 [==============================] - 137s 980ms/step - loss: 0.8771 - accuracy: 0.5815 - val_loss: 0.9030 - val_accuracy: 0.5531
# Epoch 5/50
# 140/140 [==============================] - 138s 986ms/step - loss: 0.8391 - accuracy: 0.6047 - val_loss: 0.8097 - val_accuracy: 0.6234
# Epoch 6/50
# 140/140 [==============================] - 138s 984ms/step - loss: 0.7923 - accuracy: 0.6440 - val_loss: 0.7753 - val_accuracy: 0.6385
# Epoch 7/50
# 140/140 [==============================] - 138s 986ms/step - loss: 0.7336 - accuracy: 0.6692 - val_loss: 0.7443 - val_accuracy: 0.6839
# Epoch 8/50
# 140/140 [==============================] - 138s 985ms/step - loss: 0.6933 - accuracy: 0.6906 - val_loss: 0.7769 - val_accuracy: 0.6286
# Epoch 9/50
# 140/140 [==============================] - 146s 1s/step - loss: 0.6167 - accuracy: 0.7355 - val_loss: 0.6690 - val_accuracy: 0.6969
# Epoch 10/50
# 140/140 [==============================] - 147s 1s/step - loss: 0.5583 - accuracy: 0.7643 - val_loss: 0.6340 - val_accuracy: 0.7229
# Epoch 11/50
# 140/140 [==============================] - 142s 1s/step - loss: 0.4797 - accuracy: 0.8074 - val_loss: 0.6473 - val_accuracy: 0.7156
# Epoch 12/50
# 140/140 [==============================] - 144s 1s/step - loss: 0.4482 - accuracy: 0.8203 - val_loss: 0.6152 - val_accuracy: 0.7453
# Epoch 13/50
# 140/140 [==============================] - 156s 1s/step - loss: 0.3796 - accuracy: 0.8542 - val_loss: 0.5415 - val_accuracy: 0.7661
# Epoch 14/50
# 140/140 [==============================] - 150s 1s/step - loss: 0.3191 - accuracy: 0.8775 - val_loss: 0.5396 - val_accuracy: 0.7922
# Epoch 15/50
# 140/140 [==============================] - 148s 1s/step - loss: 0.2655 - accuracy: 0.9027 - val_loss: 0.5603 - val_accuracy: 0.7781
# Epoch 16/50
# 140/140 [==============================] - 147s 1s/step - loss: 0.2083 - accuracy: 0.9306 - val_loss: 0.4964 - val_accuracy: 0.8089
# Epoch 17/50
# 140/140 [==============================] - 146s 1s/step - loss: 0.1738 - accuracy: 0.9408 - val_loss: 0.4632 - val_accuracy: 0.8250
# Epoch 18/50
# 140/140 [==============================] - 146s 1s/step - loss: 0.1486 - accuracy: 0.9522 - val_loss: 0.3891 - val_accuracy: 0.8536
# Epoch 19/50
# 140/140 [==============================] - 147s 1s/step - loss: 0.1133 - accuracy: 0.9661 - val_loss: 0.4090 - val_accuracy: 0.8484
# Epoch 20/50
# 140/140 [==============================] - 148s 1s/step - loss: 0.0855 - accuracy: 0.9786 - val_loss: 0.3954 - val_accuracy: 0.8516
# Epoch 21/50
# 140/140 [==============================] - 147s 1s/step - loss: 0.0642 - accuracy: 0.9844 - val_loss: 0.4078 - val_accuracy: 0.8568
# Epoch 22/50
# 140/140 [==============================] - 146s 1s/step - loss: 0.0593 - accuracy: 0.9859 - val_loss: 0.4447 - val_accuracy: 0.8469
# Epoch 23/50
# 140/140 [==============================] - 146s 1s/step - loss: 0.0338 - accuracy: 0.9953 - val_loss: 0.4258 - val_accuracy: 0.8661
# Epoch 24/50
# 140/140 [==============================] - 157s 1s/step - loss: 0.0197 - accuracy: 0.9991 - val_loss: 0.3852 - val_accuracy: 0.8807
# Epoch 25/50
# 140/140 [==============================] - 150s 1s/step - loss: 0.0125 - accuracy: 0.9996 - val_loss: 0.3976 - val_accuracy: 0.8745
# Epoch 26/50
# 140/140 [==============================] - 147s 1s/step - loss: 0.0110 - accuracy: 0.9998 - val_loss: 0.3986 - val_accuracy: 0.8833
# Epoch 27/50
# 140/140 [==============================] - 146s 1s/step - loss: 0.0066 - accuracy: 1.0000 - val_loss: 0.3956 - val_accuracy: 0.8885
# Epoch 28/50
# 140/140 [==============================] - 148s 1s/step - loss: 0.0050 - accuracy: 1.0000 - val_loss: 0.3967 - val_accuracy: 0.8885
# Epoch 29/50
# 140/140 [==============================] - 148s 1s/step - loss: 0.0042 - accuracy: 1.0000 - val_loss: 0.4179 - val_accuracy: 0.8885
# Epoch 30/50
# 140/140 [==============================] - 148s 1s/step - loss: 0.0031 - accuracy: 1.0000 - val_loss: 0.4089 - val_accuracy: 0.8870
# Epoch 31/50
# 140/140 [==============================] - 145s 1s/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 0.4205 - val_accuracy: 0.8870
# Epoch 32/50
# 140/140 [==============================] - 149s 1s/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.4206 - val_accuracy: 0.8865
# Epoch 33/50
# 140/140 [==============================] - 148s 1s/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.4310 - val_accuracy: 0.8880
# Epoch 34/50
# 140/140 [==============================] - 149s 1s/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.4339 - val_accuracy: 0.8875
# Epoch 35/50
# 140/140 [==============================] - 146s 1s/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.4364 - val_accuracy: 0.8885
# Epoch 36/50
# 140/140 [==============================] - 146s 1s/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.4419 - val_accuracy: 0.8880
# Epoch 37/50
# 140/140 [==============================] - 147s 1s/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.4476 - val_accuracy: 0.8875
# Epoch 38/50
# 140/140 [==============================] - 147s 1s/step - loss: 8.4432e-04 - accuracy: 1.0000 - val_loss: 0.4579 - val_accuracy: 0.8885
# Epoch 39/50
# 140/140 [==============================] - 150s 1s/step - loss: 7.5902e-04 - accuracy: 1.0000 - val_loss: 0.4798 - val_accuracy: 0.8885
# Epoch 40/50
# 140/140 [==============================] - 149s 1s/step - loss: 6.6011e-04 - accuracy: 1.0000 - val_loss: 0.4687 - val_accuracy: 0.8859
# Epoch 41/50
# 140/140 [==============================] - 142s 1s/step - loss: 5.8731e-04 - accuracy: 1.0000 - val_loss: 0.4816 - val_accuracy: 0.8880
# Epoch 42/50
# 140/140 [==============================] - 144s 1s/step - loss: 5.5165e-04 - accuracy: 1.0000 - val_loss: 0.4825 - val_accuracy: 0.8922
# Epoch 43/50
# 140/140 [==============================] - 141s 1s/step - loss: 4.5980e-04 - accuracy: 1.0000 - val_loss: 0.4804 - val_accuracy: 0.8880
# Epoch 44/50
# 140/140 [==============================] - 142s 1s/step - loss: 3.9606e-04 - accuracy: 1.0000 - val_loss: 0.4900 - val_accuracy: 0.8880
# Epoch 45/50
# 140/140 [==============================] - 142s 1s/step - loss: 3.6004e-04 - accuracy: 1.0000 - val_loss: 0.4961 - val_accuracy: 0.8911
# Epoch 46/50
# 140/140 [==============================] - 142s 1s/step - loss: 3.2051e-04 - accuracy: 1.0000 - val_loss: 0.4929 - val_accuracy: 0.8854
# Epoch 47/50
# 140/140 [==============================] - 142s 1s/step - loss: 2.7519e-04 - accuracy: 1.0000 - val_loss: 0.5001 - val_accuracy: 0.8885
# Epoch 48/50
# 140/140 [==============================] - 142s 1s/step - loss: 2.4995e-04 - accuracy: 1.0000 - val_loss: 0.5033 - val_accuracy: 0.8891
# Epoch 49/50
# 140/140 [==============================] - 143s 1s/step - loss: 2.2293e-04 - accuracy: 1.0000 - val_loss: 0.5092 - val_accuracy: 0.8917
# Epoch 50/50
# 140/140 [==============================] - 142s 1s/step - loss: 1.9918e-04 - accuracy: 1.0000 - val_loss: 0.5098 - val_accuracy: 0.8880

# %%
#Plotting the trend of the metrics during training

fig, ax = plt.subplots(1, 3, figsize = (30, 5))
ax = ax.ravel()

for i, metric in enumerate(["accuracy", "loss"]):
    ax[i].plot(history.history[metric])
    ax[i].plot(history.history["val_" + metric])
    ax[i].set_title("Model {}".format(metric))
    ax[i].set_xlabel("Epochs")
    ax[i].set_ylabel(metric)
    ax[i].legend(["train", "test"])

# %%
# %matplotlib inline

import matplotlib.image  as mpimg
import matplotlib.pyplot as plt


acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(len(acc))

plt.plot(epochs, acc, 'r', label = 'Training Accuracy')
plt.plot(epochs, val_acc, 'b', label = 'Testing Accuracy')
plt.title('Training and Testing accuracy')
plt.legend(loc = 'best')
plt.show()

plt.plot(epochs, loss, 'r', label = 'Training Loss')
plt.plot(epochs, val_loss, 'b', label = 'Testing Loss')
plt.title('Training and Testing accuracy')
plt.legend(loc = 'best')
plt.show()

# %%
#Evaluating the model on the data

#train_scores = model.evaluate(train_data, train_labels)
#val_scores = model.evaluate(val_data, val_labels)
test_scores = model.evaluate(test_data, test_labels)

#print("Training Accuracy: %.2f%%"%(train_scores[1] * 100))
#print("Validation Accuracy: %.2f%%"%(val_scores[1] * 100))
print("Testing Accuracy: %.2f%%"%(test_scores[1] * 100))
# Out:
# 60/60 [==============================] - 11s 189ms/step - loss: 0.5098 - accuracy: 0.8880
# Testing Accuracy: 88.80%

# %%
#Predicting the test data

pred_labels = model.predict(test_data)
# Out:
# 60/60 [==============================] - 12s 190ms/step

# %%
#Print the classification report of the tested data

#Since the labels are softmax arrays, we need to roundoff to have it in the form of 0s and 1s,
#similar to the test_labels
from sklearn.metrics import classification_report, confusion_matrix
def roundoff(arr):
    """To round off according to the argmax of each predicted label array. """
    arr[np.argwhere(arr != arr.max())] = 0
    arr[np.argwhere(arr == arr.max())] = 1
    return arr

for labels in pred_labels:
    labels = roundoff(labels)

print(classification_report(test_labels, pred_labels, target_names=[ 'MildDemented',
            'ModerateDemented',
            'NonDemented',
            'VeryMildDemented']))
# Out:
#                   precision    recall  f1-score   support
#
#     MildDemented       0.84      0.82      0.83       283
# ModerateDemented       1.00      0.85      0.92        13
#      NonDemented       0.92      0.92      0.92       967
# VeryMildDemented       0.86      0.88      0.87       657
#
#        micro avg       0.89      0.89      0.89      1920
#        macro avg       0.90      0.86      0.88      1920
#     weighted avg       0.89      0.89      0.89      1920
#      samples avg       0.89      0.89      0.89      1920

# %%
import seaborn as sns
pred_ls = np.argmax(pred_labels, axis=1)
test_ls = np.argmax(test_labels, axis=1)

conf_arr = confusion_matrix(test_ls, pred_ls)

plt.figure(figsize=(8, 6), dpi=80, facecolor='w', edgecolor='k')

ax = sns.heatmap(conf_arr, cmap='Greens', annot=True, fmt='d', xticklabels= [ 'MildDemented',
            'ModerateDemented',
            'NonDemented',
            'VeryMildDemented'],
                yticklabels=[ 'MildDemented',
            'ModerateDemented',
            'NonDemented',
            'VeryMildDemented'])

plt.title('Alzheimer\'s Disease Diagnosis')
plt.xlabel('Prediction')
plt.ylabel('Truth')
plt.show(ax)

# %%
model.save('modelAlzheimer.h5')

# %%
print(np.max(history.history['val_accuracy']))
print(np.min(history.history['val_accuracy']))
print(np.mean(history.history['val_accuracy']))
# Out:
# 0.8921874761581421
# 0.5093749761581421
# 0.8147708261013031

# %%
print(np.max(history.history['val_loss']))
print(np.min(history.history['val_loss']))
print(np.mean(history.history['val_loss']))
# Out:
# 0.9715566635131836
# 0.3852183520793915
# 0.5315945583581925
