# %%
import zipfile, os
local_zip = 'dataset.zip'
zip_ref = zipfile.ZipFile(local_zip,'r')
zip_ref.extractall()
zip_ref.close()

# %%
from distutils.dir_util import copy_tree, remove_tree

base_dir = "Alzheimer_s Dataset/"
root_dir = "./"
test_dir = base_dir + "test/"
train_dir = base_dir + "train/"
work_dir = root_dir + "dataset/"

if os.path.exists(work_dir):
    remove_tree(work_dir)
    

os.mkdir(work_dir)
copy_tree(train_dir, work_dir)
copy_tree(test_dir, work_dir)
print("Working Directory Contents:", os.listdir(work_dir))
# Out:
# Working Directory Contents: ['MildDemented', 'ModerateDemented', 'NonDemented', 'VeryMildDemented']

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator as IDG
import matplotlib.pyplot as plt
from random import randint
import numpy as np

ZOOM = [.99, 1.01]
BRIGHT_RANGE = [0.8, 1.2]
HORZ_FLIP = True
FILL_MODE = "constant"
DATA_FORMAT = "channels_last"

work_dr = IDG(
    rescale = 1./255, 
    brightness_range=BRIGHT_RANGE, 
    zoom_range=ZOOM, 
    data_format=DATA_FORMAT, 
    fill_mode=FILL_MODE, 
    horizontal_flip=HORZ_FLIP)
WORK_DIR = './dataset/'
IMG_SIZE = 128
IMAGE_SIZE = [128, 128]
DIM = (IMG_SIZE, IMG_SIZE)
train_data_gen = work_dr.flow_from_directory(
    directory=WORK_DIR, 
    target_size=DIM, 
    batch_size=6400, 
    shuffle=False)

def show_images(generator,y_pred=None):
    """
    Input: An image generator,predicted labels (optional)
    Output: Displays a grid of 9 images with lables
    """
    
    # get image lables
    Classes = [ 'MildDemented',
            'ModerateDemented',
            'NonDemented',
            'VeryMildDemented']
    labels =dict(zip([0,1,2,3], Classes))
    
    # get a batch of images
    x,y = generator.next()
    
    # display a grid of 9 images
    plt.figure(figsize=(10, 10))
    if y_pred is None:
        for i in range(9):
            ax = plt.subplot(3, 3, i + 1)
            idx = randint(0, 6400)
            plt.imshow(x[idx])
            plt.axis("off")
            plt.title("Class:{}".format(labels[np.argmax(y[idx])]))
                                                     
    else:
        for i in range(9):
            ax = plt.subplot(3, 3, i + 1)
            plt.imshow(x[i])
            plt.axis("off")
            plt.title("Actual:{} \nPredicted:{}".format(labels[np.argmax(y[i])],labels[y_pred[i]]))
    
# Display Train Images
show_images(train_data_gen)
# Memasukan data
train_data, train_labels = train_data_gen.next()
print(train_data.shape, train_labels.shape)
# Out:
# Found 6400 images belonging to 4 classes.
# (6400, 128, 128, 3) (6400, 4)

# %%
from sklearn.model_selection import train_test_split
train_data, test_data, train_labels, test_labels = train_test_split(train_data, train_labels, test_size = 0.2, random_state=11)
print(len(train_data), len(test_data))
# Out:
# 5120 1280

# %%
import tensorflow as tf
from tensorflow.keras import datasets, layers, models
model = tf.keras.models.Sequential([
          tf.keras.layers.Conv2D(128, (3, 3), activation = 'relu', input_shape = (128, 128, 3)),
          tf.keras.layers.MaxPooling2D(2, 2),
          tf.keras.layers.Conv2D(64, (3, 3), activation = 'relu'),
          tf.keras.layers.MaxPooling2D(2, 2),
          tf.keras.layers.Conv2D(32, (3, 3), activation = 'relu'),
          tf.keras.layers.MaxPooling2D(2, 2),
          tf.keras.layers.Flatten(),
          tf.keras.layers.Dense(500, activation = 'relu'),
          tf.keras.layers.Dense(200, activation = 'relu'),
          tf.keras.layers.Dense(4, activation = 'softmax')
])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 126, 126, 128)     3584
#
#  max_pooling2d (MaxPooling2D  (None, 63, 63, 128)      0
#  )
#
#  conv2d_1 (Conv2D)           (None, 61, 61, 64)        73792
#
#  max_pooling2d_1 (MaxPooling  (None, 30, 30, 64)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 28, 28, 32)        18464
#
#  max_pooling2d_2 (MaxPooling  (None, 14, 14, 32)       0
#  2D)
#
#  flatten (Flatten)           (None, 6272)              0
#
#  dense (Dense)               (None, 500)               3136500
#
#  dense_1 (Dense)             (None, 200)               100200
#
#  dense_2 (Dense)             (None, 4)                 804
#
# =================================================================
# Total params: 3,333,344
# Trainable params: 3,333,344
# Non-trainable params: 0
# _________________________________________________________________

# %%
from tensorflow import keras
from tensorflow.keras import datasets, layers, models
model.compile(optimizer=keras.optimizers.Adam(learning_rate=0.0001),
                              loss=tf.losses.CategoricalCrossentropy(),
                              metrics=['accuracy'])

history = model.fit(train_data, train_labels, epochs=50, 
                    validation_data=(test_data, test_labels))
# Out:
# Epoch 1/50
# 160/160 [==============================] - 157s 972ms/step - loss: 1.0293 - accuracy: 0.5049 - val_loss: 0.9867 - val_accuracy: 0.5383
# Epoch 2/50
# 160/160 [==============================] - 159s 995ms/step - loss: 0.9580 - accuracy: 0.5385 - val_loss: 0.8911 - val_accuracy: 0.5836
# Epoch 3/50
# 160/160 [==============================] - 159s 995ms/step - loss: 0.8993 - accuracy: 0.5750 - val_loss: 0.8356 - val_accuracy: 0.6211
# Epoch 4/50
# 160/160 [==============================] - 162s 1s/step - loss: 0.8612 - accuracy: 0.6004 - val_loss: 0.8123 - val_accuracy: 0.6281
# Epoch 5/50
# 160/160 [==============================] - 159s 993ms/step - loss: 0.8045 - accuracy: 0.6287 - val_loss: 0.9157 - val_accuracy: 0.5703
# Epoch 6/50
# 160/160 [==============================] - 162s 1s/step - loss: 0.7526 - accuracy: 0.6598 - val_loss: 0.7509 - val_accuracy: 0.6602
# Epoch 7/50
# 160/160 [==============================] - 161s 1s/step - loss: 0.6783 - accuracy: 0.7000 - val_loss: 0.6805 - val_accuracy: 0.7031
# Epoch 8/50
# 160/160 [==============================] - 166s 1s/step - loss: 0.5926 - accuracy: 0.7467 - val_loss: 0.6641 - val_accuracy: 0.7125
# Epoch 9/50
# 160/160 [==============================] - 149s 934ms/step - loss: 0.5086 - accuracy: 0.7912 - val_loss: 0.6191 - val_accuracy: 0.7289
# Epoch 10/50
# 160/160 [==============================] - 164s 1s/step - loss: 0.4460 - accuracy: 0.8205 - val_loss: 0.6538 - val_accuracy: 0.7031
# Epoch 11/50
# 160/160 [==============================] - 154s 963ms/step - loss: 0.3821 - accuracy: 0.8520 - val_loss: 0.5971 - val_accuracy: 0.7508
# Epoch 12/50
# 160/160 [==============================] - 156s 977ms/step - loss: 0.3337 - accuracy: 0.8682 - val_loss: 0.5466 - val_accuracy: 0.7852
# Epoch 13/50
# 160/160 [==============================] - 165s 1s/step - loss: 0.2485 - accuracy: 0.9113 - val_loss: 0.5014 - val_accuracy: 0.7984
# Epoch 14/50
# 160/160 [==============================] - 159s 995ms/step - loss: 0.2154 - accuracy: 0.9203 - val_loss: 0.4850 - val_accuracy: 0.8234
# Epoch 15/50
# 160/160 [==============================] - 163s 1s/step - loss: 0.1651 - accuracy: 0.9426 - val_loss: 0.3814 - val_accuracy: 0.8539
# Epoch 16/50
# 160/160 [==============================] - 164s 1s/step - loss: 0.1177 - accuracy: 0.9604 - val_loss: 0.7355 - val_accuracy: 0.7648
# Epoch 17/50
# 160/160 [==============================] - 159s 993ms/step - loss: 0.0993 - accuracy: 0.9701 - val_loss: 0.4049 - val_accuracy: 0.8602
# Epoch 18/50
# 160/160 [==============================] - 157s 983ms/step - loss: 0.0923 - accuracy: 0.9701 - val_loss: 0.3909 - val_accuracy: 0.8648
# Epoch 19/50
# 160/160 [==============================] - 155s 966ms/step - loss: 0.0572 - accuracy: 0.9852 - val_loss: 0.3675 - val_accuracy: 0.8875
# Epoch 20/50
# 160/160 [==============================] - 157s 980ms/step - loss: 0.0345 - accuracy: 0.9945 - val_loss: 0.4011 - val_accuracy: 0.8852
# Epoch 21/50
# 160/160 [==============================] - 154s 961ms/step - loss: 0.0199 - accuracy: 0.9990 - val_loss: 0.4027 - val_accuracy: 0.8898
# Epoch 22/50
# 160/160 [==============================] - 158s 988ms/step - loss: 0.0176 - accuracy: 0.9986 - val_loss: 0.3834 - val_accuracy: 0.9000
# Epoch 23/50
# 160/160 [==============================] - 157s 983ms/step - loss: 0.0132 - accuracy: 0.9988 - val_loss: 0.4363 - val_accuracy: 0.8875
# Epoch 24/50
# 160/160 [==============================] - 157s 980ms/step - loss: 0.0199 - accuracy: 0.9955 - val_loss: 0.4279 - val_accuracy: 0.8836
# Epoch 25/50
# 160/160 [==============================] - 161s 1s/step - loss: 0.0948 - accuracy: 0.9658 - val_loss: 0.4093 - val_accuracy: 0.8820
# Epoch 26/50
# 160/160 [==============================] - 164s 1s/step - loss: 0.0077 - accuracy: 0.9994 - val_loss: 0.3905 - val_accuracy: 0.9000
# Epoch 27/50
# 160/160 [==============================] - 158s 985ms/step - loss: 0.0041 - accuracy: 1.0000 - val_loss: 0.3991 - val_accuracy: 0.9047
# Epoch 28/50
# 160/160 [==============================] - 169s 1s/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 0.4143 - val_accuracy: 0.9000
# Epoch 29/50
# 160/160 [==============================] - 153s 957ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.4170 - val_accuracy: 0.9070
# Epoch 30/50
# 160/160 [==============================] - 153s 957ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.4291 - val_accuracy: 0.9016
# Epoch 31/50
# 160/160 [==============================] - 161s 1s/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.4267 - val_accuracy: 0.9078
# Epoch 32/50
# 160/160 [==============================] - 159s 997ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.4529 - val_accuracy: 0.9023
# Epoch 33/50
# 160/160 [==============================] - 162s 1s/step - loss: 8.9262e-04 - accuracy: 1.0000 - val_loss: 0.4561 - val_accuracy: 0.9039
# Epoch 34/50
# 160/160 [==============================] - 163s 1s/step - loss: 7.9346e-04 - accuracy: 1.0000 - val_loss: 0.4451 - val_accuracy: 0.9016
# Epoch 35/50
# 160/160 [==============================] - 161s 1s/step - loss: 6.6342e-04 - accuracy: 1.0000 - val_loss: 0.4577 - val_accuracy: 0.9031
# Epoch 36/50
# 160/160 [==============================] - 161s 1s/step - loss: 5.8118e-04 - accuracy: 1.0000 - val_loss: 0.4695 - val_accuracy: 0.9016
# Epoch 37/50
# 160/160 [==============================] - 164s 1s/step - loss: 5.3018e-04 - accuracy: 1.0000 - val_loss: 0.4615 - val_accuracy: 0.9023
# Epoch 38/50
# 160/160 [==============================] - 159s 994ms/step - loss: 4.5677e-04 - accuracy: 1.0000 - val_loss: 0.4690 - val_accuracy: 0.9039
# Epoch 39/50
# 160/160 [==============================] - 158s 986ms/step - loss: 4.0626e-04 - accuracy: 1.0000 - val_loss: 0.4682 - val_accuracy: 0.9055
# Epoch 40/50
# 160/160 [==============================] - 155s 969ms/step - loss: 3.5466e-04 - accuracy: 1.0000 - val_loss: 0.4841 - val_accuracy: 0.9047
# Epoch 41/50
# 160/160 [==============================] - 161s 1s/step - loss: 3.1257e-04 - accuracy: 1.0000 - val_loss: 0.4859 - val_accuracy: 0.9047
# Epoch 42/50
# 160/160 [==============================] - 164s 1s/step - loss: 2.7778e-04 - accuracy: 1.0000 - val_loss: 0.4924 - val_accuracy: 0.9039
# Epoch 43/50
# 160/160 [==============================] - 167s 1s/step - loss: 2.4609e-04 - accuracy: 1.0000 - val_loss: 0.5059 - val_accuracy: 0.9039
# Epoch 44/50
# 160/160 [==============================] - 165s 1s/step - loss: 2.1968e-04 - accuracy: 1.0000 - val_loss: 0.4980 - val_accuracy: 0.9078
# Epoch 45/50
# 160/160 [==============================] - 164s 1s/step - loss: 1.9189e-04 - accuracy: 1.0000 - val_loss: 0.5036 - val_accuracy: 0.9070
# Epoch 46/50
# 160/160 [==============================] - 163s 1s/step - loss: 1.7153e-04 - accuracy: 1.0000 - val_loss: 0.5174 - val_accuracy: 0.9047
# Epoch 47/50
# 160/160 [==============================] - 166s 1s/step - loss: 1.5893e-04 - accuracy: 1.0000 - val_loss: 0.5152 - val_accuracy: 0.9062
# Epoch 48/50
# 160/160 [==============================] - 166s 1s/step - loss: 1.4199e-04 - accuracy: 1.0000 - val_loss: 0.5224 - val_accuracy: 0.9094
# Epoch 49/50
# 160/160 [==============================] - 165s 1s/step - loss: 1.2424e-04 - accuracy: 1.0000 - val_loss: 0.5324 - val_accuracy: 0.9023
# Epoch 50/50
# 160/160 [==============================] - 166s 1s/step - loss: 1.1341e-04 - accuracy: 1.0000 - val_loss: 0.5363 - val_accuracy: 0.9070

# %%
#Plotting the trend of the metrics during training

fig, ax = plt.subplots(1, 3, figsize = (30, 5))
ax = ax.ravel()

for i, metric in enumerate(["accuracy", "loss"]):
    ax[i].plot(history.history[metric])
    ax[i].plot(history.history["val_" + metric])
    ax[i].set_title("Model {}".format(metric))
    ax[i].set_xlabel("Epochs")
    ax[i].set_ylabel(metric)
    ax[i].legend(["train", "test"])

# %%
# %matplotlib inline

import matplotlib.image  as mpimg
import matplotlib.pyplot as plt


acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(len(acc))

plt.plot(epochs, acc, 'r', label = 'Training Accuracy')
plt.plot(epochs, val_acc, 'b', label = 'Testing Accuracy')
plt.title('Training and Testing accuracy')
plt.legend(loc = 'best')
plt.show()

plt.plot(epochs, loss, 'r', label = 'Training Loss')
plt.plot(epochs, val_loss, 'b', label = 'Testing Loss')
plt.title('Training and Testing accuracy')
plt.legend(loc = 'best')
plt.show()

# %%
#Evaluating the model on the data

#train_scores = model.evaluate(train_data, train_labels)
#val_scores = model.evaluate(val_data, val_labels)
test_scores = model.evaluate(test_data, test_labels)

#print("Training Accuracy: %.2f%%"%(train_scores[1] * 100))
#print("Validation Accuracy: %.2f%%"%(val_scores[1] * 100))
print("Testing Accuracy: %.2f%%"%(test_scores[1] * 100))
# Out:
# 40/40 [==============================] - 7s 185ms/step - loss: 0.5363 - accuracy: 0.9070
# Testing Accuracy: 90.70%

# %%
#Predicting the test data

pred_labels = model.predict(test_data)
# Out:
# 40/40 [==============================] - 8s 184ms/step

# %%
#Print the classification report of the tested data

#Since the labels are softmax arrays, we need to roundoff to have it in the form of 0s and 1s,
#similar to the test_labels
from sklearn.metrics import classification_report, confusion_matrix
def roundoff(arr):
    """To round off according to the argmax of each predicted label array. """
    arr[np.argwhere(arr != arr.max())] = 0
    arr[np.argwhere(arr == arr.max())] = 1
    return arr

for labels in pred_labels:
    labels = roundoff(labels)

print(classification_report(test_labels, pred_labels, target_names=[ 'MildDemented',
            'ModerateDemented',
            'NonDemented',
            'VeryMildDemented']))
# Out:
#                   precision    recall  f1-score   support
#
#     MildDemented       0.89      0.81      0.85       190
# ModerateDemented       1.00      0.86      0.92         7
#      NonDemented       0.94      0.94      0.94       660
# VeryMildDemented       0.87      0.90      0.88       423
#
#        micro avg       0.91      0.91      0.91      1280
#        macro avg       0.92      0.88      0.90      1280
#     weighted avg       0.91      0.91      0.91      1280
#      samples avg       0.91      0.91      0.91      1280

# %%
import seaborn as sns
pred_ls = np.argmax(pred_labels, axis=1)
test_ls = np.argmax(test_labels, axis=1)

conf_arr = confusion_matrix(test_ls, pred_ls)

plt.figure(figsize=(8, 6), dpi=80, facecolor='w', edgecolor='k')

ax = sns.heatmap(conf_arr, cmap='Greens', annot=True, fmt='d', xticklabels= [ 'MildDemented',
            'ModerateDemented',
            'NonDemented',
            'VeryMildDemented'],
                yticklabels=[ 'MildDemented',
            'ModerateDemented',
            'NonDemented',
            'VeryMildDemented'])

plt.title('Alzheimer\'s Disease Diagnosis')
plt.xlabel('Prediction')
plt.ylabel('Truth')
plt.show(ax)

# %%
model.save('modelAlzheimer.h5')
