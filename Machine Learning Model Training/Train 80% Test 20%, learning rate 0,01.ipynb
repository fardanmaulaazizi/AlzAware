# %%
import zipfile, os
local_zip = 'dataset.zip'
zip_ref = zipfile.ZipFile(local_zip,'r')
zip_ref.extractall()
zip_ref.close()

# %%
from distutils.dir_util import copy_tree, remove_tree

base_dir = "Alzheimer_s Dataset/"
root_dir = "./"
test_dir = base_dir + "test/"
train_dir = base_dir + "train/"
work_dir = root_dir + "dataset/"

if os.path.exists(work_dir):
    remove_tree(work_dir)
    

os.mkdir(work_dir)
copy_tree(train_dir, work_dir)
copy_tree(test_dir, work_dir)
print("Working Directory Contents:", os.listdir(work_dir))
# Out:
# Working Directory Contents: ['MildDemented', 'ModerateDemented', 'NonDemented', 'VeryMildDemented']

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator as IDG
import matplotlib.pyplot as plt
from random import randint
import numpy as np

ZOOM = [.99, 1.01]
BRIGHT_RANGE = [0.8, 1.2]
HORZ_FLIP = True
FILL_MODE = "constant"
DATA_FORMAT = "channels_last"

work_dr = IDG(
    rescale = 1./255, 
    brightness_range=BRIGHT_RANGE, 
    zoom_range=ZOOM, 
    data_format=DATA_FORMAT, 
    fill_mode=FILL_MODE, 
    horizontal_flip=HORZ_FLIP)
WORK_DIR = './dataset/'
IMG_SIZE = 128
IMAGE_SIZE = [128, 128]
DIM = (IMG_SIZE, IMG_SIZE)
train_data_gen = work_dr.flow_from_directory(
    directory=WORK_DIR, 
    target_size=DIM, 
    batch_size=6400, 
    shuffle=False)

def show_images(generator,y_pred=None):
    """
    Input: An image generator,predicted labels (optional)
    Output: Displays a grid of 9 images with lables
    """
    
    # get image lables
    Classes = [ 'MildDemented',
            'ModerateDemented',
            'NonDemented',
            'VeryMildDemented']
    labels =dict(zip([0,1,2,3], Classes))
    
    # get a batch of images
    x,y = generator.next()
    
    # display a grid of 9 images
    plt.figure(figsize=(10, 10))
    if y_pred is None:
        for i in range(9):
            ax = plt.subplot(3, 3, i + 1)
            idx = randint(0, 6400)
            plt.imshow(x[idx])
            plt.axis("off")
            plt.title("Class:{}".format(labels[np.argmax(y[idx])]))
                                                     
    else:
        for i in range(9):
            ax = plt.subplot(3, 3, i + 1)
            plt.imshow(x[i])
            plt.axis("off")
            plt.title("Actual:{} \nPredicted:{}".format(labels[np.argmax(y[i])],labels[y_pred[i]]))
    
# Display Train Images
show_images(train_data_gen)
# Memasukan data
train_data, train_labels = train_data_gen.next()
print(train_data.shape, train_labels.shape)
# Out:
# Found 6400 images belonging to 4 classes.
# (6400, 128, 128, 3) (6400, 4)

# %%
from sklearn.model_selection import train_test_split
train_data, test_data, train_labels, test_labels = train_test_split(train_data, train_labels, test_size = 0.2, random_state=11)
print(len(train_data), len(test_data))
# Out:
# 5120 1280

# %%
import tensorflow as tf
from tensorflow.keras import datasets, layers, models
model = tf.keras.models.Sequential([
          tf.keras.layers.Conv2D(128, (3, 3), activation = 'relu', input_shape = (128, 128, 3)),
          tf.keras.layers.MaxPooling2D(2, 2),
          tf.keras.layers.Conv2D(64, (3, 3), activation = 'relu'),
          tf.keras.layers.MaxPooling2D(2, 2),
          tf.keras.layers.Conv2D(32, (3, 3), activation = 'relu'),
          tf.keras.layers.MaxPooling2D(2, 2),
          tf.keras.layers.Flatten(),
          tf.keras.layers.Dense(500, activation = 'relu'),
          tf.keras.layers.Dense(200, activation = 'relu'),
          tf.keras.layers.Dense(4, activation = 'softmax')
])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 126, 126, 128)     3584
#
#  max_pooling2d (MaxPooling2D  (None, 63, 63, 128)      0
#  )
#
#  conv2d_1 (Conv2D)           (None, 61, 61, 64)        73792
#
#  max_pooling2d_1 (MaxPooling  (None, 30, 30, 64)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 28, 28, 32)        18464
#
#  max_pooling2d_2 (MaxPooling  (None, 14, 14, 32)       0
#  2D)
#
#  flatten (Flatten)           (None, 6272)              0
#
#  dense (Dense)               (None, 500)               3136500
#
#  dense_1 (Dense)             (None, 200)               100200
#
#  dense_2 (Dense)             (None, 4)                 804
#
# =================================================================
# Total params: 3,333,344
# Trainable params: 3,333,344
# Non-trainable params: 0
# _________________________________________________________________

# %%
from tensorflow import keras
from tensorflow.keras import datasets, layers, models
model.compile(optimizer=keras.optimizers.Adam(learning_rate=0.01),
                              loss=tf.losses.CategoricalCrossentropy(),
                              metrics=['accuracy'])

history = model.fit(train_data, train_labels, epochs=50, 
                    validation_data=(test_data, test_labels))
# Out:
# Epoch 1/50
# 160/160 [==============================] - 203s 1s/step - loss: 1.4495 - accuracy: 0.4809 - val_loss: 1.0245 - val_accuracy: 0.5156
# Epoch 2/50
# 160/160 [==============================] - 200s 1s/step - loss: 1.0438 - accuracy: 0.4943 - val_loss: 1.0268 - val_accuracy: 0.5156
# Epoch 3/50
# 160/160 [==============================] - 214s 1s/step - loss: 1.0424 - accuracy: 0.4961 - val_loss: 1.0203 - val_accuracy: 0.5156
# Epoch 4/50
# 160/160 [==============================] - 218s 1s/step - loss: 1.0443 - accuracy: 0.4961 - val_loss: 1.0219 - val_accuracy: 0.5156
# Epoch 5/50
# 160/160 [==============================] - 219s 1s/step - loss: 1.0431 - accuracy: 0.4961 - val_loss: 1.0207 - val_accuracy: 0.5156
# Epoch 6/50
# 160/160 [==============================] - 203s 1s/step - loss: 1.0417 - accuracy: 0.4961 - val_loss: 1.0196 - val_accuracy: 0.5156
# Epoch 7/50
# 160/160 [==============================] - 170s 1s/step - loss: 1.0420 - accuracy: 0.4961 - val_loss: 1.0306 - val_accuracy: 0.5156
# Epoch 8/50
# 160/160 [==============================] - 154s 965ms/step - loss: 1.0424 - accuracy: 0.4961 - val_loss: 1.0225 - val_accuracy: 0.5156
# Epoch 9/50
# 160/160 [==============================] - 153s 956ms/step - loss: 1.0411 - accuracy: 0.4961 - val_loss: 1.0247 - val_accuracy: 0.5156
# Epoch 10/50
# 160/160 [==============================] - 150s 940ms/step - loss: 1.0416 - accuracy: 0.4961 - val_loss: 1.0243 - val_accuracy: 0.5156
# Epoch 11/50
# 160/160 [==============================] - 145s 905ms/step - loss: 1.0408 - accuracy: 0.4961 - val_loss: 1.0274 - val_accuracy: 0.5156
# Epoch 12/50
# 160/160 [==============================] - 145s 908ms/step - loss: 1.0398 - accuracy: 0.4961 - val_loss: 1.0226 - val_accuracy: 0.5156
# Epoch 13/50
# 160/160 [==============================] - 154s 963ms/step - loss: 1.0410 - accuracy: 0.4961 - val_loss: 1.0287 - val_accuracy: 0.5156
# Epoch 14/50
# 160/160 [==============================] - 147s 919ms/step - loss: 1.0416 - accuracy: 0.4961 - val_loss: 1.0226 - val_accuracy: 0.5156
# Epoch 15/50
# 160/160 [==============================] - 147s 921ms/step - loss: 1.0408 - accuracy: 0.4961 - val_loss: 1.0255 - val_accuracy: 0.5156
# Epoch 16/50
# 160/160 [==============================] - 147s 920ms/step - loss: 1.0406 - accuracy: 0.4961 - val_loss: 1.0207 - val_accuracy: 0.5156
# Epoch 17/50
# 160/160 [==============================] - 145s 905ms/step - loss: 1.0407 - accuracy: 0.4961 - val_loss: 1.0208 - val_accuracy: 0.5156
# Epoch 18/50
# 160/160 [==============================] - 148s 923ms/step - loss: 1.0413 - accuracy: 0.4961 - val_loss: 1.0220 - val_accuracy: 0.5156
# Epoch 19/50
# 160/160 [==============================] - 145s 909ms/step - loss: 1.0405 - accuracy: 0.4961 - val_loss: 1.0234 - val_accuracy: 0.5156
# Epoch 20/50
# 160/160 [==============================] - 149s 932ms/step - loss: 1.0405 - accuracy: 0.4961 - val_loss: 1.0231 - val_accuracy: 0.5156
# Epoch 21/50
# 160/160 [==============================] - 146s 916ms/step - loss: 1.0417 - accuracy: 0.4961 - val_loss: 1.0234 - val_accuracy: 0.5156
# Epoch 22/50
# 160/160 [==============================] - 144s 902ms/step - loss: 1.0397 - accuracy: 0.4961 - val_loss: 1.0223 - val_accuracy: 0.5156
# Epoch 23/50
# 160/160 [==============================] - 144s 903ms/step - loss: 1.0401 - accuracy: 0.4961 - val_loss: 1.0233 - val_accuracy: 0.5156
# Epoch 24/50
# 160/160 [==============================] - 145s 905ms/step - loss: 1.0420 - accuracy: 0.4961 - val_loss: 1.0236 - val_accuracy: 0.5156
# Epoch 25/50
# 160/160 [==============================] - 144s 899ms/step - loss: 1.0402 - accuracy: 0.4961 - val_loss: 1.0238 - val_accuracy: 0.5156
# Epoch 26/50
# 160/160 [==============================] - 144s 900ms/step - loss: 1.0400 - accuracy: 0.4961 - val_loss: 1.0236 - val_accuracy: 0.5156
# Epoch 27/50
# 160/160 [==============================] - 8123s 51s/step - loss: 1.0411 - accuracy: 0.4961 - val_loss: 1.0242 - val_accuracy: 0.5156
# Epoch 28/50
# 160/160 [==============================] - 157s 983ms/step - loss: 1.0402 - accuracy: 0.4961 - val_loss: 1.0261 - val_accuracy: 0.5156
# Epoch 29/50
# 160/160 [==============================] - 144s 899ms/step - loss: 1.0420 - accuracy: 0.4961 - val_loss: 1.0221 - val_accuracy: 0.5156
# Epoch 30/50
# 160/160 [==============================] - 144s 898ms/step - loss: 1.0400 - accuracy: 0.4961 - val_loss: 1.0238 - val_accuracy: 0.5156
# Epoch 31/50
# 160/160 [==============================] - 144s 900ms/step - loss: 1.0411 - accuracy: 0.4961 - val_loss: 1.0264 - val_accuracy: 0.5156
# Epoch 32/50
# 160/160 [==============================] - 144s 901ms/step - loss: 1.0404 - accuracy: 0.4961 - val_loss: 1.0254 - val_accuracy: 0.5156
# Epoch 33/50
# 160/160 [==============================] - 148s 925ms/step - loss: 1.0408 - accuracy: 0.4961 - val_loss: 1.0223 - val_accuracy: 0.5156
# Epoch 34/50
# 160/160 [==============================] - 145s 905ms/step - loss: 1.0402 - accuracy: 0.4961 - val_loss: 1.0288 - val_accuracy: 0.5156
# Epoch 35/50
# 160/160 [==============================] - 148s 927ms/step - loss: 1.0405 - accuracy: 0.4961 - val_loss: 1.0243 - val_accuracy: 0.5156
# Epoch 36/50
# 160/160 [==============================] - 148s 924ms/step - loss: 1.0403 - accuracy: 0.4961 - val_loss: 1.0216 - val_accuracy: 0.5156
# Epoch 37/50
# 160/160 [==============================] - 148s 928ms/step - loss: 1.0409 - accuracy: 0.4961 - val_loss: 1.0240 - val_accuracy: 0.5156
# Epoch 38/50
# 160/160 [==============================] - 147s 920ms/step - loss: 1.0409 - accuracy: 0.4961 - val_loss: 1.0222 - val_accuracy: 0.5156
# Epoch 39/50
# 160/160 [==============================] - 144s 904ms/step - loss: 1.0395 - accuracy: 0.4961 - val_loss: 1.0271 - val_accuracy: 0.5156
# Epoch 40/50
# 160/160 [==============================] - 145s 905ms/step - loss: 1.0406 - accuracy: 0.4961 - val_loss: 1.0241 - val_accuracy: 0.5156
# Epoch 41/50
# 160/160 [==============================] - 144s 902ms/step - loss: 1.0400 - accuracy: 0.4961 - val_loss: 1.0271 - val_accuracy: 0.5156
# Epoch 42/50
# 160/160 [==============================] - 144s 901ms/step - loss: 1.0402 - accuracy: 0.4961 - val_loss: 1.0209 - val_accuracy: 0.5156
# Epoch 43/50
# 160/160 [==============================] - 144s 903ms/step - loss: 1.0399 - accuracy: 0.4961 - val_loss: 1.0238 - val_accuracy: 0.5156
# Epoch 44/50
# 160/160 [==============================] - 145s 904ms/step - loss: 1.0404 - accuracy: 0.4961 - val_loss: 1.0230 - val_accuracy: 0.5156
# Epoch 45/50
# 160/160 [==============================] - 145s 905ms/step - loss: 1.0400 - accuracy: 0.4961 - val_loss: 1.0255 - val_accuracy: 0.5156
# Epoch 46/50
# 160/160 [==============================] - 144s 903ms/step - loss: 1.0404 - accuracy: 0.4961 - val_loss: 1.0243 - val_accuracy: 0.5156
# Epoch 47/50
# 160/160 [==============================] - 144s 903ms/step - loss: 1.0406 - accuracy: 0.4961 - val_loss: 1.0252 - val_accuracy: 0.5156
# Epoch 48/50
# 160/160 [==============================] - 145s 904ms/step - loss: 1.0403 - accuracy: 0.4961 - val_loss: 1.0223 - val_accuracy: 0.5156
# Epoch 49/50
# 160/160 [==============================] - 144s 903ms/step - loss: 1.0403 - accuracy: 0.4961 - val_loss: 1.0219 - val_accuracy: 0.5156
# Epoch 50/50
# 160/160 [==============================] - 151s 943ms/step - loss: 1.0396 - accuracy: 0.4961 - val_loss: 1.0229 - val_accuracy: 0.5156

# %%
#Plotting the trend of the metrics during training

fig, ax = plt.subplots(1, 3, figsize = (30, 5))
ax = ax.ravel()

for i, metric in enumerate(["accuracy", "loss"]):
    ax[i].plot(history.history[metric])
    ax[i].plot(history.history["val_" + metric])
    ax[i].set_title("Model {}".format(metric))
    ax[i].set_xlabel("Epochs")
    ax[i].set_ylabel(metric)
    ax[i].legend(["train", "test"])

# %%
# %matplotlib inline

import matplotlib.image  as mpimg
import matplotlib.pyplot as plt


acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(len(acc))

plt.plot(epochs, acc, 'r', label = 'Training Accuracy')
plt.plot(epochs, val_acc, 'b', label = 'Testing Accuracy')
plt.title('Training and Validation accuracy')
plt.legend(loc = 'best')
plt.show()

plt.plot(epochs, loss, 'r', label = 'Training Loss')
plt.plot(epochs, val_loss, 'b', label = 'Testing Loss')
plt.title('Training and Testing accuracy')
plt.legend(loc = 'best')
plt.show()

# %%
#Evaluating the model on the data

#train_scores = model.evaluate(train_data, train_labels)
#val_scores = model.evaluate(val_data, val_labels)
test_scores = model.evaluate(test_data, test_labels)

#print("Training Accuracy: %.2f%%"%(train_scores[1] * 100))
#print("Validation Accuracy: %.2f%%"%(val_scores[1] * 100))
print("Testing Accuracy: %.2f%%"%(test_scores[1] * 100))
# Out:
# 40/40 [==============================] - 7s 185ms/step - loss: 1.0229 - accuracy: 0.5156
# Testing Accuracy: 51.56%

# %%
#Predicting the test data

pred_labels = model.predict(test_data)
# Out:
# 40/40 [==============================] - 7s 183ms/step

# %%
#Print the classification report of the tested data

#Since the labels are softmax arrays, we need to roundoff to have it in the form of 0s and 1s,
#similar to the test_labels
from sklearn.metrics import classification_report, confusion_matrix
def roundoff(arr):
    """To round off according to the argmax of each predicted label array. """
    arr[np.argwhere(arr != arr.max())] = 0
    arr[np.argwhere(arr == arr.max())] = 1
    return arr

for labels in pred_labels:
    labels = roundoff(labels)

print(classification_report(test_labels, pred_labels, target_names=[ 'MildDemented',
            'ModerateDemented',
            'NonDemented',
            'VeryMildDemented']))
# Out:
#                   precision    recall  f1-score   support
#
#     MildDemented       0.00      0.00      0.00       190
# ModerateDemented       0.00      0.00      0.00         7
#      NonDemented       0.52      1.00      0.68       660
# VeryMildDemented       0.00      0.00      0.00       423
#
#        micro avg       0.52      0.52      0.52      1280
#        macro avg       0.13      0.25      0.17      1280
#     weighted avg       0.27      0.52      0.35      1280
#      samples avg       0.52      0.52      0.52      1280
# C:\Users\Fardan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
import seaborn as sns
pred_ls = np.argmax(pred_labels, axis=1)
test_ls = np.argmax(test_labels, axis=1)

conf_arr = confusion_matrix(test_ls, pred_ls)

plt.figure(figsize=(8, 6), dpi=80, facecolor='w', edgecolor='k')

ax = sns.heatmap(conf_arr, cmap='Greens', annot=True, fmt='d', xticklabels= [ 'MildDemented',
            'ModerateDemented',
            'NonDemented',
            'VeryMildDemented'],
                yticklabels=[ 'MildDemented',
            'ModerateDemented',
            'NonDemented',
            'VeryMildDemented'])

plt.title('Alzheimer\'s Disease Diagnosis')
plt.xlabel('Prediction')
plt.ylabel('Truth')
plt.show(ax)

# %%
model.save('modelAlzheimer.h5')

# %%
print(np.max(history.history['val_accuracy']))
print(np.min(history.history['val_accuracy']))
print(np.mean(history.history['val_accuracy']))
# Out:
# 0.515625
# 0.515625
# 0.515625

# %%
print(np.max(history.history['val_loss']))
print(np.min(history.history['val_loss']))
print(np.mean(history.history['val_loss']))
# Out:
# 1.0306018590927124
# 1.019644021987915
# 1.023847646713257
